# %% [markdown]
# <div style="
#     background: linear-gradient(to right, #614385 ,rgba(226, 63, 136, 0.61));
#     padding: 20px;
#     border-radius: 10px;
#     box-shadow: 0 4px 15px rgba(0, 0, 0, 0.2);
#     text-align: center;
#     max-width: 800px;
#     margin: 20px auto;
#     transition: transform 0.3s ease, box-shadow 0.3s ease;
# "
#     onmouseover="this.style.transform='scale(1.05)'; this.style.boxShadow='0 6px 20px rgba(0, 0, 0, 0.4)';"
#     onmouseout="this.style.transform='scale(1)'; this.style.boxShadow='0 4px 15px rgba(0, 0, 0, 0.2)';"
# >
#     <h1 style="
#         color: #FFDDE1;
#         font-size: 40px;
#         font-family: 'Paytone One', sans-serif;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3);
#         letter-spacing: 2px;
#     ">
#         Data Wrangling
#     </h1>
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(to right,rgb(1, 84, 109),rgba(219, 0, 0, 0.37));
#     padding: 5px;
#     border-radius: 15px;
#     box-shadow: 0 6px 20px rgba(0, 0, 0, 0.3);
#     text-align: center;
#     max-width: 1400px;
#     margin: 50px auto;
#     font-family: 'Arial', sans-serif;
#     transition: transform 0.3s ease, box-shadow 0.3s ease;
# "
#     onmouseover="this.style.transform='scale(1.05)'; this.style.boxShadow='0 8px 25px rgba(0, 0, 0, 0.5)';"
#     onmouseout="this.style.transform='scale(1)'; this.style.boxShadow='0 6px 20px rgba(0, 0, 0, 0.3)';"
# >
#     <h1 style="
#         color: #FFDDE1;
#         font-size: 45px;
#         font-family: 'Paytone One', sans-serif;
#         text-shadow: 3px 3px 5px rgba(0, 0, 0, 0.3);
#         letter-spacing: 2px;
#         margin-bottom: 20px;
#     ">
#         Lab 4 Assignment
#     </h1>
#     <h2 style="
#         color: #ffffff;
#         font-size: 25px;
#         font-weight: 400;
#         margin-bottom: 10px;
#     ">
#         Data Science
#     </h2>
#     <p style="
#         color: #f0f0f0;
#         font-size: 18px;
#         margin: 5px 0;
#     ">
#         Submitted by: <strong>Bhim Prasad Upadhaya</strong>
#     </h2>
#     <p style="
#         color: #f0f0f0;
#         font-size: 18px;
#         margin: 5px 0;
#     ">
#         Roll No.: <strong>080BCT019</strong>
#     </p>
#     <p style="
#         color: #f0f0f0;
#         font-size: 18px;
#         margin: 5px 0;
#     ">
#         Institute: <strong>Pulchowk Campus</strong>
#     </p>
# </div>

# %% [markdown]
# <div style="
#     background-color: #F5F5F5;
#     padding: 20px;
#     border-radius: 10px;
#     box-shadow: 0 4px 15px rgba(0, 0, 0, 0.2);
#     max-width: 1500px;
#     margin: 30px auto;
#     font-family: 'Awesome', sans-serif;
#     color: #000000;
#     line-height: 1.6;
#     font-size: 18px;
#     text-align: justify;
# ">
#     <h1 style="
#         text-align: center;
#         font-size: 24px;
#         margin-bottom: 15px;
#         color: #333333;
#     "><strong>
#         Data Wrangling</strong>
#     </h1>
#     <p>
#         Data wrangling is the process of converting raw data into a usable form. It may also be called data munging or data remediation.
#     </p>
#     <p>
#         Data wrangling describes a series of processes designed to explore, transform, and validate raw datasets from their messy and complex forms into high-quality data. You can use your wrangled data to produce valuable insights and guide business decision.
#     </p>
#     <p>
#         The process for data wrangling in Python requires <strong>Pandas</strong>.
#     </p>
# </div>

# %% [markdown]
# <div style="
#     background-color: #F5F5F5;
#     padding: 20px;
#     border-radius: 10px;
#     box-shadow: 0 4px 15px rgba(0, 0, 0, 0.2);
#     max-width: 800px;
#     margin: 30px auto;
#     font-family: Arial, sans-serif;
#     color: #000000;
#     line-height: 1.6;
#     font-size: 18px;
#     text-align: justify;
# ">
#     <p>
#         The data wrangling process has four broad steps::<br><br>
#         <strong>Discovery</strong> - In the discovery stage, you'll essentially prepare yourself for the rest of the process. Here, you'll think about the questions you want to answer and the type of data you'll need in order to answer them. You'll also locate the data you plan to use and examine its current form in order to figure out how you'll clean, structure, and organize your data in the following stages..<br>
#         <strong>Transformation</strong> - During the transformation stage, you'll act on the plan you developed during the discovery stage. This piece of the process can be broken down into four components: structuring, normalizing and denormalizing, cleaning, and enriching.<br>
#         <strong>Validation</strong> - During the validation step, you essentially check the work you did during the transformation stage, verifying that your data is consistent, of sufficient quality, and secure. This step may be completed using automated processes and can require some programming skills.<br>
#         <strong>Publishing</strong> - After you've finished validating your data, you're ready to publish it. When you publish data, you'll put it into whatever file format you prefer for sharing with other team members for downstream analysis purposes.<br>
#     </p>
# </div>

# %% [markdown]
# <div style="
#     background-color:rgb(14, 43, 77);
#     padding: 20px;
#     border-radius: 10px;
#     box-shadow: 0 4px 15px rgba(0, 0, 0, 0.3);
#     max-width: 1400px;
#     margin: 30px auto;
#     font-family: 'Arial', sans-serif;
#     color: #FFFFFF;
#     font-size: 14px;
#     line-height: 1.8;
#     text-align: justify;
# ">
#     <p>
#         <strong>Problem 1.</strong> On the same data that you performed wrangling on in the lab:-
#     </p>
#     <p>
#       Clean the STARS column to extract new Directors and Actors columns.
#     </p>
#     <p>
#     Then obtain a rating of each actor, by averaging the rating across all the movies that theyʼve played
# in. And then plot the ratings of thus obtained top 10 actors.
#     </p>
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_name = "movies.csv"
df = pd.read_csv(file_name)

df[['Directors', 'Actors']] = df['STARS'].str.split(',', n=1, expand=True)
df['Directors'] = df['Directors'].str.replace('Director:', '').str.strip()  # Clean the 'Directors' column
df['Actors'] = df['Actors'].str.strip()  # Clean the 'Actors' column

df = df[df['Actors'].notna() & (df['Actors'] != '')]

actors_list = df['Actors'].str.split(',').explode().str.strip()

actors_df = pd.DataFrame({
    'Actor': actors_list, 
    'Rating': df.loc[actors_list.index, 'RATING'].values  
})

average_actor_ratings = actors_df.groupby('Actor')['Rating'].mean().sort_values(ascending=False)

top_10_actors = average_actor_ratings.head(10)

plt.figure(figsize=(12, 6))
top_10_actors.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title("Top 10 Actors by Average Rating")
plt.xlabel("Actor")
plt.ylabel("Average Rating")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="
#     background-color:rgb(14, 43, 77);
#     padding: 20px;
#     border-radius: 10px;
#     box-shadow: 0 4px 15px rgba(0, 0, 0, 0.3);
#     max-width: 1400px;
#     margin: 30px auto;
#     font-family: 'Arial', sans-serif;
#     color: #FFFFFF;
#     font-size: 14px;
#     line-height: 1.8;
#     text-align: justify;
# ">
#     <p>
#         <strong>Problem 2.</strong>Download the data for this assignment at:
# https://www.kaggle.com/datasets/tonygordonjr/spotify-dataset-2023/data
# <br>
# Tasks:
# <br>
# 1. Import all 5 CSV files as Pandas DataFrames, print their schemas,
# then perform data cleaning if found to be necessary
#     </p>
#
# </div>

# %%
import pandas as pd

csv_files = [
    "spotify_artist_data_2023.csv",
    "spotify_data_12_20_2023.csv",
    "spotify_features_data_2023.csv",
    "spotify_tracks_data_2023.csv",
    "spotify-albums_data_2023.csv"
]

dataframes = {}

for file in csv_files:
    df_name = file.replace('.csv', '').replace('-', '_')
    df = pd.read_csv(file)
    dataframes[df_name] = df
    print(f"Schema for {df_name}:")
    print(df.info(), "\n")

for name, df in dataframes.items():
    print(f"Cleaning {name}...")
    
    duplicate_count = df.duplicated().sum()
    if duplicate_count > 0:
        print(f"  Removing {duplicate_count} duplicate rows.")
        df.drop_duplicates(inplace=True)
    
    missing_values = df.isnull().sum()
    if missing_values.any():
        print(f"  Missing values detected:\n{missing_values}")
        print("  Filling missing values with appropriate strategies.")
        for column in df.columns:
            if df[column].dtype in ['float64', 'int64']:
                df[column].fillna(df[column].median(), inplace=True)
            else:
                df[column].fillna("Unknown", inplace=True)
    
    df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

    dataframes[name] = df

print("Data cleaning completed for all files.")
# Out:
# Schema for spotify_artist_data_2023:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37012 entries, 0 to 37011
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 37012 non-null  object
#  1   name               37012 non-null  object
#  2   artist_popularity  37012 non-null  int64
#  3   artist_genres      37012 non-null  object
#  4   followers          37012 non-null  int64
#  5   genre_0            10947 non-null  object
#  6   genre_1            4820 non-null   object
#  7   genre_2            2440 non-null   object
#  8   genre_3            1365 non-null   object
#  9   genre_4            718 non-null    object
#  10  genre_5            0 non-null      float64
#  11  genre_6            0 non-null      float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 3.4+ MB
# None
# ...

# %% [markdown]
# <div style="
#     background-color:rgb(14, 43, 77);
#     padding: 20px;
#     border-radius: 10px;
#     box-shadow: 0 4px 15px rgba(0, 0, 0, 0.3);
#     max-width: 1400px;
#     margin: 30px auto;
#     font-family: 'Arial', sans-serif;
#     color: #FFFFFF;
#     font-size: 14px;
#     line-height: 1.8;
#     text-align: justify;
# ">
#     <p>
#         <strong>2.</strong> In  spotify-artist-data_2023.csv :<br>
# Count the number of distinct artists.<br>
# Count the number of distinct artist genres.<br>
# Display a bar graph showing follower count of top 10 artists with the most followers
#     </p>
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_name = "spotify_artist_data_2023.csv"
df = pd.read_csv(file_name)

df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

distinct_artists = df['name'].nunique()
print(f"Number of distinct artists: {distinct_artists}")

distinct_genres = df['artist_genres'].nunique()
print(f"Number of distinct artist genres: {distinct_genres}")

if 'followers' in df.columns and 'name' in df.columns:
    top_artists = df.nlargest(10, 'followers')[['name', 'followers']]
    plt.figure(figsize=(10, 6))
    plt.barh(top_artists['name'], top_artists['followers'], color='skyblue')
    plt.xlabel('Follower Count')
    plt.ylabel('Artist Name')
    plt.title('Top 10 Artists with the Most Followers')
    plt.gca().invert_yaxis()
    plt.tight_layout()
    plt.show()
else:
    print("Required columns ('name' or 'followers') are missing.")
# Out:
# Number of distinct artists: 36196
# Number of distinct artist genres: 6408

# %% [markdown]
# <div style="
#     background-color:rgb(14, 43, 77);
#     padding: 20px;
#     border-radius: 10px;
#     box-shadow: 0 4px 15px rgba(0, 0, 0, 0.3);
#     max-width: 1400px;
#     margin: 30px auto;
#     font-family: 'Arial', sans-serif;
#     color: #FFFFFF;
#     font-size: 14px;
#     line-height: 1.8;
#     text-align: justify;
# ">
#     <p>
#         <strong>3.</strong>In the  spotify_features_data_2023.csv :<br>
# Calculate basic statistics of each feature (quartiles, min, max, variance etc.)<br>
# Plot the correlation between each feature using a heatmap.<br>
# Can any conclusion can be drawn from the heatmap?
#     </p>
# </div>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

file_name = "spotify_features_data_2023.csv"
df = pd.read_csv(file_name)

numeric_df = df.select_dtypes(include=['float64', 'int64'])

statistics = numeric_df.describe().transpose() 
statistics['variance'] = numeric_df.var()  
print("Basic Statistics for each numeric feature:")
print(statistics)

correlation_matrix = numeric_df.corr()

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", cbar=True)
plt.title("Correlation Heatmap of Features")
plt.show()

print("\nConclusions from the heatmap:")
for column in correlation_matrix.columns:
    highly_correlated = correlation_matrix[column][correlation_matrix[column] > 0.7].index.tolist()
    if len(highly_correlated) > 1:  
        print(f"- {column} is highly correlated with {', '.join(highly_correlated)}")
# Out:
# Basic Statistics for each numeric feature:
#                      count           mean            std     min          25%  \
# danceability      438112.0       0.573555       0.190432     0.0       0.4550
# energy            438112.0       0.528345       0.264231     0.0       0.3230
# key               438112.0       5.237617       3.579329     0.0       2.0000
# loudness          438112.0     -11.155534       6.472758   -60.0     -13.9160
# mode              438112.0       0.638287       0.480497     0.0       0.0000
# speechiness       438112.0       0.112228       0.156232     0.0       0.0363
# acousticness      438112.0       0.384170       0.359647     0.0       0.0375
# instrumentalness  438112.0       0.265504       0.379555     0.0       0.0000
# liveness          438112.0       0.194991       0.172597     0.0       0.0970
# valence           438112.0       0.457240       0.267000     0.0       0.2330
# ...

# %% [markdown]
# <div style="
#     background-color:rgb(14, 43, 77);
#     padding: 20px;
#     border-radius: 10px;
#     box-shadow: 0 4px 15px rgba(0, 0, 0, 0.3);
#     max-width: 1400px;
#     margin: 30px auto;
#     font-family: 'Arial', sans-serif;
#     color: #FFFFFF;
#     font-size: 14px;
#     line-height: 1.8;
#     text-align: justify;
# ">
#     <p>
#         <strong>4.</strong>In the  spotify_tracks_data_2023.csv :<br>
# Find the top 10 tracks with highest popularity
#     </p>
# </div>

# %%
import pandas as pd

file_name = "spotify_tracks_data_2023.csv"
df = pd.read_csv(file_name)

top_10_tracks = df[['id', 'track_popularity']].sort_values(by='track_popularity', ascending=False).head(10)

print("Top 10 Tracks with Highest Popularity:")
print(top_10_tracks)
# Out:
# Top 10 Tracks with Highest Popularity:
#                             id  track_popularity
# 385079  1BxfuPKGuaTgP7aM0Bbdwr                99
# 385080  0bYg9bo50gSsH3LtXe2SQn                99
# 385078  3vkCueOmm7xQDoJ17W1Pm3                98
# 438937  7iQXYTyuG13aoeHxGG28Nh                97
# 438936  4MjDJD8cW7iVeWInc2Bdyj                96
# 438935  6uIIdjYTxxpWOyWuVXrKQO                95
# 385077  0lizgQ7Qw35od7CYaoMBZb                95
# 385075  6wf7Yu7cxBSPrRlWeSeK0Q                94
# 385073  1Iq8oo9XkmmvCQiGOfORiz                94
# 438934  7MXVkk9YMctZqd1Srtv4MB                94

# %% [markdown]
# <div style="
#     background-color:rgb(14, 43, 77);
#     padding: 20px;
#     border-radius: 10px;
#     box-shadow: 0 4px 15px rgba(0, 0, 0, 0.3);
#     max-width: 1400px;
#     margin: 30px auto;
#     font-family: 'Arial', sans-serif;
#     color: #FFFFFF;
#     font-size: 14px;
#     line-height: 1.8;
#     text-align: justify;
# ">
#     <p>
#         <strong>5.</strong>In  spotify-albums-data_2023.csv :<br>
# Count total number of distinct albums.<br>
# Draw a pie chart showing distribution of album types (single, compilation or album).<br>
# Find the album with the most tracks.<br>
# Find the top 10 popular albums.<br>
# Plot the average track duration of the top 10 albums in a bar graph.<br>
# Plot number of tracks per album for the top 10 albums in a bar graph<br>
#     </p>
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_name = "spotify-albums_data_2023.csv"
df = pd.read_csv(file_name)

distinct_albums_count = df['album_id'].nunique()
print(f"Total number of distinct albums: {distinct_albums_count}")

album_type_counts = df['album_type'].value_counts()
plt.figure(figsize=(8, 8))
album_type_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['#ff9999','#66b3ff','#99ff99'])
plt.title('Distribution of Album Types')
plt.ylabel('')
plt.show()

album_with_most_tracks = df.groupby('album_id')['track_id'].nunique().idxmax()
album_with_most_tracks_info = df[df['album_id'] == album_with_most_tracks].iloc[0]
print(f"Album with the most tracks: {album_with_most_tracks_info['album_name']} (ID: {album_with_most_tracks_info['album_id']})")

top_10_albums = df[['album_name', 'album_popularity']].sort_values(by='album_popularity', ascending=False).head(10)
print("\nTop 10 Popular Albums:")
print(top_10_albums)

top_10_album_ids = top_10_albums['album_name'].values
plt.figure(figsize=(12, 6))
average_duration_by_album.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title("Average Track Duration of the Top 10 Albums")
plt.xlabel("Album Name")
plt.ylabel("Average Duration (Minutes)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

tracks_per_album = df[df['album_name'].isin(top_10_album_ids)].groupby('album_name')['track_id'].nunique()
plt.figure(figsize=(12, 6))
tracks_per_album.plot(kind='bar', color='lightgreen', edgecolor='black')
plt.title("Number of Tracks per Album for the Top 10 Albums")
plt.xlabel("Album Name")
plt.ylabel("Number of Tracks")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Total number of distinct albums: 78172
# Album with the most tracks: 50 Soothing Rain Sounds For Ultimate Spa Relaxation (ID: 03GacOzf8YlKD1sGPbQbaT)
#
# Top 10 Popular Albums:
#                                  album_name  album_popularity
# 438964  Nadie Sabe Lo Que Va A Pasar Mañana               100
# 438972  Nadie Sabe Lo Que Va A Pasar Mañana               100
# 438968  Nadie Sabe Lo Que Va A Pasar Mañana               100
# 438962  Nadie Sabe Lo Que Va A Pasar Mañana               100
# 438963  Nadie Sabe Lo Que Va A Pasar Mañana               100
# 438966  Nadie Sabe Lo Que Va A Pasar Mañana               100
# 438953  Nadie Sabe Lo Que Va A Pasar Mañana               100
# 438961  Nadie Sabe Lo Que Va A Pasar Mañana               100
# 438954  Nadie Sabe Lo Que Va A Pasar Mañana               100
# 438971  Nadie Sabe Lo Que Va A Pasar Mañana               100

# %% [markdown]
# <div style="
#     background-color:rgb(14, 43, 77);
#     padding: 20px;
#     border-radius: 10px;
#     box-shadow: 0 4px 15px rgba(0, 0, 0, 0.3);
#     max-width: 1400px;
#     margin: 30px auto;
#     font-family: 'Arial', sans-serif;
#     color: #FFFFFF;
#     font-size: 14px;
#     line-height: 1.8;
#     text-align: justify;
# ">
#     <p>
#         <strong>6.</strong>In the joined data  spotify_data_12_20_2023.csv :<br>
# Find top 10 popular tracks.<br>
# Count the number of tracks of each artist.<br>
# Identify the artists with the highest average danceability.<br>
# Plot the average popularity of each genre.<br>
# Display line plot for the total number of album releases each year after 1920.<br>
# Display line plot for average album duration each year after 1920
#     </p>
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_name = "spotify_data_12_20_2023.csv"
df = pd.read_csv(file_name)

top_10_tracks = df[['track_name', 'track_popularity']].sort_values(by='track_popularity', ascending=False).head(10)
print("Top 10 Popular Tracks:")
print(top_10_tracks)

df['primary_artist'] = df['artists'].apply(lambda x: x.split(',')[0] if isinstance(x, str) else x)
tracks_per_artist = df['primary_artist'].value_counts()
print("\nNumber of Tracks per Artist:")
print(tracks_per_artist)

average_danceability = df.groupby('primary_artist')['danceability'].mean().sort_values(ascending=False)
top_danceability_artists = average_danceability.head(10)
print("\nArtists with the Highest Average Danceability:")
print(top_danceability_artists)

genre_columns = ['genre_0', 'genre_1', 'genre_2', 'genre_3', 'genre_4']
df['all_genres'] = df[genre_columns].apply(lambda x: ','.join(x.dropna()), axis=1)
average_popularity_by_genre = df.explode('all_genres').groupby('all_genres')['track_popularity'].mean().sort_values(ascending=False)

plt.figure(figsize=(12, 6))
average_popularity_by_genre.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title("Average Popularity of Each Genre")
plt.xlabel("Genre")
plt.ylabel("Average Popularity")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

df['release_year'] = pd.to_datetime(df['release_date'], errors='coerce').dt.year  
album_releases_by_year = df[df['release_year'] > 1920].groupby('release_year').size()

plt.figure(figsize=(12, 6))
album_releases_by_year.plot(kind='line', marker='o', color='orange')
plt.title("Total Number of Album Releases Each Year (After 1920)")
plt.xlabel("Year")
plt.ylabel("Number of Album Releases")
plt.grid(True)
plt.show()

df['duration_minutes'] = df['duration_ms'] / 60000
average_duration_by_year = df[df['release_year'] > 1920].groupby('release_year')['duration_minutes'].mean()

plt.figure(figsize=(12, 6))
average_duration_by_year.plot(kind='line', marker='o', color='green')
plt.title("Average Album Duration Each Year (After 1920)")
plt.xlabel("Year")
plt.ylabel("Average Duration (Minutes)")
plt.grid(True)
plt.show()
# Out:
# C:\Users\Bhim Prasad Upadhaya\AppData\Local\Temp\ipykernel_4596\1459083915.py:5: DtypeWarning: Columns (25,26,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_name)
# Top 10 Popular Tracks:
#                                                track_name  track_popularity
# 374458                                       Cruel Summer              99.0
# 364635                    All I Want For Christmas Is You              99.0
# 361959                              My Love Mine All Mine              98.0
# 374139                                        Perro Negro              97.0
# 374103                                             Monaco              96.0
# 344602                                           Que Onda              95.0
# 364438                                          As It Was              94.0
# 373279                                            Starboy              94.0
# ...

# %% [markdown]
# <div style="
# background-color: #333333; /* Solid dark gray background */
# padding: 20px;
# border-radius: 10px;
# box-shadow: 0 4px 15px rgba(0, 0, 0, 0.2);
# text-align: left;
# max-width: 1200px;
# margin: 20px auto;
# transition: transform 0.3s ease, box-shadow 0.3s ease;
# "
# onmouseover="this.style.transform='scale(1.05)'; this.style.boxShadow='0 6px 20px rgba(0, 0, 0, 0.4)';"
# onmouseout="this.style.transform='scale(1)'; this.style.boxShadow='0 4px 15px rgba(0, 0, 0, 0.2)';"
#
# <h1 style="
# color: #FFF; /* White text color /
# font-size: 36px; / Larger heading size */
# font-family: 'Paytone One', sans-serif;
# text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3);
# letter-spacing: 2px;
# ">
# <strong>Discussion and Conclusion</strong>
# </h1>
#
# <p style="
# color: #DDD; /* Light gray text color /
# font-size: 18px; / Larger paragraph text size */
# font-family: 'Roboto', sans-serif;
# ">
# This project involved the analysis and wrangling of both movie and music data, with the aim of extracting meaningful insights and trends.
# </p>
#
#
# <p style="
# color: #DDD; /* Light gray text color /
# font-size: 18px; / Larger paragraph text size */
# font-family: 'Roboto', sans-serif;
# ">
# By cleaning and separating the 'STARS' column in the movie dataset, we identified directors and actors and calculated the average ratings for actors based on their performances across multiple movies. This allowed us to identify the top performers in the industry. In the music dataset, we explored various aspects such as artist popularity, track features, and album characteristics. We examined the relationship between features like danceability, energy, and track popularity, and analyzed trends in album releases and durations over time. The findings highlight key patterns in both the movie and music industries, such as the correlation between different song features and track success, as well as the evolving nature of album releases.
# </p>
#
# <p style="
# color: #DDD; /* Light gray text color /
# font-size: 18px; / Larger paragraph text size */
# font-family: 'Roboto', sans-serif;
# ">
#  By combining data wrangling techniques, statistical analysis, and visualizations, we gained a deeper understanding of industry trends, offering insights into how artists, tracks, and albums perform and evolve. Ultimately, this project demonstrates the power of data analysis in uncovering meaningful trends and patterns within complex datasets, contributing to a better understanding of the dynamics of the movie and music industries.
#
#
#
#
#
#
#
# </p>
# </div>
